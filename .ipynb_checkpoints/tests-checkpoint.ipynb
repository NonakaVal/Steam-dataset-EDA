# %%
pip install --upgrade jupyterlab
# Out:
# Requirement already satisfied: jupyterlab in c:\users\nonak\anaconda3\lib\site-packages (4.2.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (6.28.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (3.1.3)
# Requirement already satisfied: jupyter-core in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (5.5.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (2.27.2)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (0.2.3)
# Requirement already satisfied: packaging in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (23.2)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (6.3.3)
# Requirement already satisfied: traitlets in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab) (5.7.1)
# Requirement already satisfied: anyio in c:\users\nonak\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (4.2.0)
# Requirement already satisfied: certifi in c:\users\nonak\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\nonak\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.0.5)
# Requirement already satisfied: idna in c:\users\nonak\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (3.4)
# Requirement already satisfied: sniffio in c:\users\nonak\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\nonak\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\nonak\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\nonak\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\nonak\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.20.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\nonak\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\nonak\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\nonak\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\users\nonak\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\nonak\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (25.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nonak\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-core->jupyterlab) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-core->jupyterlab) (305.1)
# Requirement already satisfied: argon2-cffi in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.9.2)
# Requirement already satisfied: overrides in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.58.0)
# Requirement already satisfied: babel>=2.10 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\nonak\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.31.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\nonak\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.3.post1)
# Requirement already satisfied: decorator in c:\users\nonak\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nonak\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\nonak\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nonak\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\nonak\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.0)
# Requirement already satisfied: colorama in c:\users\nonak\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (2.8.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\nonak\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\nonak\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\nonak\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\nonak\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\nonak\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\nonak\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\nonak\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\nonak\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\nonak\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\nonak\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nonak\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nonak\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (1.26.18)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\nonak\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: six in c:\users\nonak\anaconda3\lib\site-packages (from websocket-client->jupyter-server<3,>=2.4.0->jupyterlab) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\nonak\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\nonak\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Requirement already satisfied: fqdn in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.1)
# Requirement already satisfied: uri-template in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\nonak\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.13)
# Requirement already satisfied: wcwidth in c:\users\nonak\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\nonak\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nonak\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.5)
# Requirement already satisfied: executing in c:\users\nonak\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\nonak\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\nonak\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\nonak\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\nonak\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd
import webbrowser
from threading import Timer

# Cria alguns dados de exemplo
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Berries"],
    "Amount": [4, 1, 2, 2],
    "City": ["SF", "SF", "SF", "SF"]
})

# Inicializa o aplicativo Dash
app = dash.Dash(__name__)

# Define o layout do aplicativo
app.layout = html.Div(children=[
    html.H1(children='Dashboard de Exemplo'),

    html.Div(children='''
        Um exemplo simples de dashboard com Dash e Plotly.
    '''),

    dcc.Graph(
        id='example-graph',
        figure=px.bar(df, x="Fruit", y="Amount", color="City", barmode="group")
    ),

    dcc.Graph(
        id='example-pie-chart',
        figure=px.pie(df, names='Fruit', values='Amount')
    ),

    html.Label('Selecione uma fruta:'),
    dcc.Dropdown(
        id='fruit-dropdown',
        options=[
            {'label': 'Maçãs', 'value': 'Apples'},
            {'label': 'Laranjas', 'value': 'Oranges'},
            {'label': 'Bananas', 'value': 'Bananas'},
            {'label': 'Frutas vermelhas', 'value': 'Berries'}
        ],
        value='Apples'
    ),

    html.Div(id='output-container')
])

# Define o callback para interatividade
@app.callback(
    Output('output-container', 'children'),
    Input('fruit-dropdown', 'value')
)
def update_output(value):
    return f'Você selecionou: {value}'

# Função para abrir o navegador
def open_browser():
    webbrowser.open_new('http://127.0.0.1:8050/')

# Roda o aplicativo
if __name__ == '__main__':
    Timer(1, open_browser).start()  # Abre o navegador após 1 segundo
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
